# %%
# !pip install numpy pandas matplotlib unidecode tensorflow transformers unidecode > /dev/null # dev null esconde output

# %%
from transformers import pipeline

# Load the NER pipeline with the Portuguese model
ner = pipeline(
    "ner",
    model="lfcc/bert-portuguese-ner",
    aggregation_strategy="first"    # merges tokens into full entities
)
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# Device set to use cpu

# %%
import requests

# Teste da API ovh
artist = "Caetano Veloso"
title = "Sozinho"
response = requests.get(f"https://api.lyrics.ovh/v1/{artist}/{title}")
print(response.json())
# Out:
# {'lyrics': 'Às vezes, no silêncio da noite\r\nEu fico imaginando nós dois\r\nEu fico ali sonhando acordado, juntando\r\no antes, o agora e o depois\r\npor que você me deixa tão solto?\r\npor que você não cola em mim?\n\nTô me sentindo muito sozinho!\n\n\n\nNão sou nem quero ser o seu dono\n\nÉ que um carinho às vezes cai bem\n\nEu tenho meus segredos e planos secretos\n\nsó abro pra você mais ninguém\n\npor que você me esquece e some?\n\ne se eu me interessar por alguém?\n\ne se ela, de repente, me ganha?\n\n\n\nQuando a gente gostaé claro que a gente cuida\n\nfala que me ama\n\nsó que é da boca pra fora\n\nou você me engana\n\nou não está madura\n\nonde está você agora?\n\n\n\nQuando a gente gostaé claro que a gente cuida\n\nfala que me ama\n\nsó que é da boca pra fora\n\nou você me engana\n\nou não está madura\n\nonde está você agora?\n\n\n\nA veces en el silencio de la noche\n\nme quedo imaginando a nosotros dos\n\nme quedo ahí, soñando despierto, juntando\n\nel antes, el ahora y el después\n\n¿Por qué me dejas tan suelto?\n\n¿por qué no te pegas a mí?\n\nMe estoy sintiendo muy solo...\n\n\n\nNo soy ni quiero ser tu dueño\n\nes que un cariño a veces cae bien\n\nYo tengo mis secretos y planes ocultos\n\nque sólo abro para tí y nadie más\n\n¿Por qué me olvidas y me hundes?\n\n¿Y si yo me interesase en alguien?\n\n¿Y si ella, de repente, me engaña?\n\n\n\nSi es que nos gustamos, es claro que nos cuidamos\n\nDice que me ama, sólo de boca hacia afuera\n\nO vos me engañas\n\no no estás madura\n\n¿dónde estás ahora?\n\n\n\n\n\n(Gracias a Maria Isabel por esta letra)'}

# %%
#top 100 musicos brasileiros segundo a rolling stone , caso o musico seja fortemente associado a uma banda a banda esta em seu lugar

artistas_brasileiros = [
    "Tom Jobim",
    "João Gilberto",
    "Chico Buarque",
    "Caetano Veloso",
    "Jorge Ben Jor",
    "The Sputniks",
    "Noel Rosa",
    "Cartola",
    "The Sputniks",
    "Gilberto Gil",
    "Dorival Caymmi",
    "Pixinguinha",
    "Luiz Gonzaga",
    "Elis Regina",
    "Os Mutantes",
    "Nação Zumbi",
    "Paulinho da Viola",
    "Vinicius de Moraes",
    "Raul Seixas",
    "Clube da Esquina",
    "Os Mutantes",
    "Maria Bethânia",
    "Heitor Villa-Lobos",
    "Rogério Duprat",
    "Legião Urbana",
    "Baden Powell",
    "Gal Costa",
    "Racionais MC's",
    "Ary Barroso",
    "Hermeto Pascoal",
    "Secos & Molhados",
    "Tom Zé",
    "João Donato",
    "Barão Vermelho",
    "Carmen Miranda",
    "Moacir Santos",
    "Erasmo Carlos",
    "Wilson Simonal",
    "Nelson Cavaquinho",
    "Cássia Eller",
    "Zé Ramalho",
    "Itamar Assumpção",
    "Marisa Monte",
    "Nara Leão",
    "Luiz Melodia",
    "Lulu Santos",
    "Sepultura",
    "Adoniran Barbosa",
    "Jackson do Pandeiro",
    "Marcos Valle",
    "Clara Nunes",
    "Sérgio Mendes",
    "Mário Reis",
    "Braguinha",
    "Elizeth Cardoso",
    "Edu Lobo",
    "Novos Baianos",
    "Alceu Valença",
    "Martinho da Vila",
    "Nelson Gonçalves",
    "Maysa",
    "Naná Vasconcelos",
    "João Bosco",
    "Lobão",
    "Jacob do Bandolim",
    "Eumir Deodato",
    "Orlando Silva",
    "Lupicínio Rodrigues",
    "Otília Amorim",
    "Egberto Gismonti",
    "Lô Borges",
    "Los Hermanos",
    "Planet Hemp",
    "Odair José",
    "Lanny Gordin",
    "Johnny Alf",
    "Dolores Duran",
    "Jards Macalé",
    "Arrigo Barnabé",
    "Djavan",
    "Lenine",
    "Zeca Pagodinho",
    "Paralamas do Sucesso",
    "Los Hermanos",
    "Mundo Livre S/A",
    "Lamartine Babo",
    "Radamés Gnattali",
    "Francisco Alves",
    "Ismael Silva",
    "Jamelão",
    "Aracy de Almeida",
    "Gang 90 e as Absurdettes",
    "Guilherme Arantes",
    "Marina Lima",
    "Titãs",
    "Daniela Mercury",
    "Nando Reis",
    "Ira!",
    "Os Mutantes",
    "Belchior"
]

# %%
import requests
import time
import os
from getpass import getpass

API_KEY = getpass('Enter your API key: ') #input para obter API Key do last.fm

BASE_URL = 'http://ws.audioscrobbler.com/2.0/'

# artists = [
#     "Caetano Veloso", "Chico Buarque", "Marisa Monte", "Gilberto Gil", "Gal Costa",
#     "Djavan", "Milton Nascimento", "Elis Regina", "Maria Bethânia", "Zeca Pagodinho",
#     "Lulu Santos", "Legião Urbana", "Engenheiros do Hawaii", "Titãs", "Os Paralamas do Sucesso",
#     "Ivete Sangalo", "Seu Jorge", "Martinho da Vila", "Jorge Ben Jor", "Cazuza",
#     "Zé Ramalho", "Lenine", "Ana Carolina", "Fagner", "Adriana Calcanhotto",
#     "Los Hermanos", "Vanessa da Mata", "Skank", "Pitty", "Roupa Nova",
#     "MC Kevinho", "Anitta", "Luan Santana", "Gusttavo Lima", "Zezé Di Camargo & Luciano",
#     "Sandy & Junior", "Simone & Simaria", "Maiara & Maraisa", "Henrique & Juliano", "Jorge & Mateus",
#     "Marília Mendonça", "Wesley Safadão", "Barões da Pisadinha", "Zeca Baleiro", "Nando Reis",
#     "Biquini Cavadão", "O Rappa", "Claudia Leitte", "Chitãozinho & Xororó", "João Bosco & Vinícius",
#     "Projota", "Emicida", "Racionais MC's", "Criolo", "Karol Conká",
#     "Mano Brown", "Gabriel o Pensador", "Rael", "Mc Poze do Rodo", "Mc Hariel"
# ]

artists = artistas_brasileiros

def get_top_tracks(artist_name):
    params = {
        'method': 'artist.getTopTracks',
        'artist': artist_name,
        'api_key': API_KEY,
        'format': 'json',
        'limit': 10
    }
    response = requests.get(BASE_URL, params=params)
    if response.status_code == 200:
        data = response.json()
        tracks = data.get('toptracks', {}).get('track', [])
        # Ensure tracks is a list
        if isinstance(tracks, dict):
            tracks = [tracks]
        return [track['name'] for track in tracks]
    else:
        print(f"Error fetching tracks for {artist_name}: {response.status_code}")
        return []

# Function to get lyrics from Lyrics.ovh
def get_lyrics(artist, title):
    url = f"https://api.lyrics.ovh/v1/{artist}/{title}"
    response = requests.get(url)
    if response.status_code == 200:
        #print(f"Lyrics found for {artist} - {title}")
        data = response.json()
        lyrics = data.get('lyrics', '')
        # Remove newline characters
        return lyrics.replace('\n', ' ').strip()
    else:
        #print(f"Lyrics not found for {artist} - {title}")
        return ''

# Main script
musicas = []

for artist in artists:
    print(f"Processing artist: {artist}")
    top_tracks = get_top_tracks(artist)
    full_lyrics = ''
    for title in top_tracks:
        lyrics = get_lyrics(artist, title)
        if lyrics:
            lyrics = lyrics.replace('\r', '')  # Remove \r
            full_lyrics += ' ' + lyrics
        time.sleep(0.5)  # To respect API rate limits
    if full_lyrics:
        musicas.append({
            'artista': artist,
            'letra': full_lyrics
        })
# Out:
# Enter your API key: ··········
# Processing artist: Tom Jobim
# Processing artist: João Gilberto
# Processing artist: Chico Buarque
# Processing artist: Caetano Veloso
# Processing artist: Jorge Ben Jor
# Processing artist: The Sputniks
# Processing artist: Noel Rosa
# Processing artist: Cartola
# Processing artist: The Sputniks
# Processing artist: Gilberto Gil
# Processing artist: Dorival Caymmi
# Processing artist: Pixinguinha
# Processing artist: Luiz Gonzaga
# Processing artist: Elis Regina
# Processing artist: Os Mutantes
# Processing artist: Nação Zumbi
# Processing artist: Paulinho da Viola
# Processing artist: Vinicius de Moraes
# Processing artist: Raul Seixas
# Processing artist: Clube da Esquina
# Processing artist: Os Mutantes
# Processing artist: Maria Bethânia
# Processing artist: Heitor Villa-Lobos
# Processing artist: Rogério Duprat
# Processing artist: Legião Urbana
# Processing artist: Baden Powell
# Processing artist: Gal Costa
# Processing artist: Racionais MC's
# Processing artist: Ary Barroso
# Processing artist: Hermeto Pascoal
# Processing artist: Secos & Molhados
# Processing artist: Tom Zé
# Processing artist: João Donato
# Processing artist: Barão Vermelho
# Processing artist: Carmen Miranda
# Processing artist: Moacir Santos
# Processing artist: Erasmo Carlos
# Processing artist: Wilson Simonal
# Processing artist: Nelson Cavaquinho
# Processing artist: Cássia Eller
# Processing artist: Zé Ramalho
# Processing artist: Itamar Assumpção
# Processing artist: Marisa Monte
# Processing artist: Nara Leão
# Processing artist: Luiz Melodia
# Processing artist: Lulu Santos
# Processing artist: Sepultura
# Processing artist: Adoniran Barbosa
# Processing artist: Jackson do Pandeiro
# Processing artist: Marcos Valle
# Processing artist: Clara Nunes
# Processing artist: Sérgio Mendes
# Processing artist: Mário Reis
# Processing artist: Braguinha
# Processing artist: Elizeth Cardoso
# Processing artist: Edu Lobo
# Processing artist: Novos Baianos
# Processing artist: Alceu Valença
# Processing artist: Martinho da Vila
# Processing artist: Nelson Gonçalves
# Processing artist: Maysa
# Processing artist: Naná Vasconcelos
# Processing artist: João Bosco
# Processing artist: Lobão
# Processing artist: Jacob do Bandolim
# Processing artist: Eumir Deodato
# Processing artist: Orlando Silva
# Processing artist: Lupicínio Rodrigues
# Processing artist: Otília Amorim
# Processing artist: Egberto Gismonti
# Processing artist: Lô Borges
# Processing artist: Los Hermanos
# Processing artist: Planet Hemp
# Processing artist: Odair José
# Processing artist: Lanny Gordin
# Processing artist: Johnny Alf
# Processing artist: Dolores Duran
# Processing artist: Jards Macalé
# Processing artist: Arrigo Barnabé
# Processing artist: Djavan
# Processing artist: Lenine
# Processing artist: Zeca Pagodinho
# Processing artist: Paralamas do Sucesso
# Processing artist: Los Hermanos
# Processing artist: Mundo Livre S/A
# Processing artist: Lamartine Babo
# Processing artist: Radamés Gnattali
# Processing artist: Francisco Alves
# Processing artist: Ismael Silva
# Processing artist: Jamelão
# Processing artist: Aracy de Almeida
# Processing artist: Gang 90 e as Absurdettes
# Processing artist: Guilherme Arantes
# Processing artist: Marina Lima
# Processing artist: Titãs
# Processing artist: Daniela Mercury
# Processing artist: Nando Reis
# Processing artist: Ira!
# Processing artist: Os Mutantes
# Processing artist: Belchior

# %%
musicas[0]
# Out:
# {'artista': 'Tom Jobim',
#  'letra': " Tall and tan and young and lovely The girl from Ipanema goes walking And when she passes, each one she passes goes a-a-ah! When she walks she's like a samba that Swings so cool and sways so gentle, That when she passes, each one she passes goes a-a-ah!  Oh, but I watch her so sadly  How can I tell her I love her?  Yes, I would give my heart gladly  But each day when she walks to the sea  She looks straight ahead not at me  Tall and tan and young and lovely  The girl from Ipanema goes walking  And when she passes I smile, but she doesn't see  She just doesn't see  No she doesn't see    (Thanks to Rafael for these lyrics) Quiet nights of quiet stars, Quiet chords from my guitar, Floating on the silence that surronds us, Quiet thoughts and quiet dreams, Quiet walks by quiet streams, And window that looking so to Corcovado,  Oh! How I lovely.    Um cantinho, um violão,  Esse amor numa canção,  Pra fazer feliz a quem se ama,  Muita calma pra pensar e ter tempo pra sonhar,  Da janela vê-se o Corcovado,  O Redentor que lindo.    Quero a vida sempre assim,  Com você perto de mim,  Até o apagar da velha chama,  E eu que era triste,  Descrente de sinismo,  Ao encontrar você eu conheci,  O que é Felicidade, Meu Amor.    O que é Felicidade, Meu Amor Vai minha tristeza e diz a ela que sem ela Não pode ser, diz-lhe numa prece Que ela regresse, porque eu não posso Mais sofrer. Chega de saudade a realidade É que sem ela não há paz, não há beleza É só tristeza e a melancolia  Que não sai de mim, não sai de mim, não sai    Mas se ela voltar, se ela voltar,  Que coisa linda, que coisa louca  Pois há menos peixinhos a nadar no mar  Do que os beijinhos que eu darei  Na sua boca, dentro dos meus braços  Os abraços hão de ser, milhões de abraços  Apertado assim, colado assim, calado assim  Abraços e beijinhos e carinhos sem ter fim  Que é pra acabar com esse negócio de você viver sem mim.  Não quero mais esse negócio de você longe de mim Quando eu vou cantar, você não deixa E sempre vêm a mesma queixa Diz que eu desafino, que eu não sei cantar Você é tão bonita, mas tua beleza também pode se enganar Se você disser que eu desafino amor  Saiba que isto em mim provoca imensa dor  Só privilegiados têm o ouvido igual ao seu  Eu possuo apenas o que Deus me deu    Se você insiste em classificar  Meu comportamento de anti-musical  Eu mesmo mentindo devo argumentar  Que isto é Bossa Nova, isto é muito natural    O que você não sabe nem sequer pressente  É que os desafinados também têm um coração  Fotografei você na minha Rolley-Flex  Revelou-se a sua enorme ingratidão    Só não poderá falar assim do meu amor  Este é o maior que você pode encontrar  Você com a sua música esqueceu o principal  Que no peito dos desafinados  No fundo do peito bate calado  Que no peito dos desafinados também bate um coração    (Thanks to Rafael for these lyrics)"}

# %%
dados_artistas = []

for m in musicas:
    letra = m['letra']
    if letra:
        palavras = letra.split()
        all_persons = []
        for i in range(0, len(palavras), 200):
            trecho = ' '.join(palavras[i:i + 200])
            ents = ner(trecho)
            persons = [e['word'] for e in ents if e['entity_group'] == 'Pessoa']
            all_persons.extend(persons)

        dados_artistas.append({
            'artista': m['artista'],
            'entidades': all_persons
        })

dados_artistas[0]
# Out:
# Asking to truncate to max_length but no maximum length is provided and the model has no predefined maximum length. Default to no truncation.
# {'artista': 'Tom Jobim', 'entidades': []}

# %%
# (sem acentos / lower-case)
from unidecode import unidecode

def normalizar(nome: str) -> str:
    return unidecode(nome).lower().strip()

# Índices únicos de artistas + entidades
nomes = list({normalizar(d['artista']) for d in dados_artistas})
indices = {nome: i for i, nome in enumerate(nomes)}

# %%
import numpy as np

# 7) Construção da matriz de adjacência

def construir_matriz_adj(dados, indices):
    N = len(indices)
    M = np.zeros((N, N), dtype=float)
    for item in dados:
        orig = normalizar(item['artista'])
        i_orig = indices[orig]
        for ent in item['entidades']:
            if ent:
                dest = normalizar(ent)
                j = indices.get(dest)
                if j is not None and j != i_orig:
                    M[j, i_orig] = 1
    return M

matriz_adj = construir_matriz_adj(dados_artistas, indices)

# %%
import matplotlib.pyplot as plt

plt.figure(figsize=(10, 10))
plt.imshow(matriz_adj, cmap='Greys', interpolation='none')
plt.title('Matriz de Adjacência')
plt.xlabel('Origem')
plt.ylabel('Destino')
plt.colorbar(label='Peso')
plt.show()

# %%
# 8) Normalização

def normalizar_colunas(M):
    N = M.shape[0]
    C = np.zeros_like(M)
    for col in range(N):
        s = M[:, col].sum()
        if s == 0:
            C[:, col] = 1.0 / N
        else:
            C[:, col] = M[:, col] / s
    return C

matriz_trans = normalizar_colunas(matriz_adj)

# %%
# 9) Cálculo de PageRank

def page_rank(M, damping=0.85, tol=1e-6, max_iter=100):
    N = M.shape[0]
    r = np.ones(N) / N
    for it in range(max_iter):
        r_new = damping * (M @ r) + (1 - damping) / N
        if np.linalg.norm(r_new - r, 1) < tol:
            break
        r = r_new
    return r

ranks = page_rank(matriz_trans)

# %%
# 10) Exibir top artistas e plotar
import pandas as pd

df = pd.DataFrame({
    'nome': nomes,
    'rank': ranks
})
df['rank'] = df['rank'].round(6)
df_sorted = df.sort_values('rank', ascending=False).reset_index(drop=True)

top10 = df_sorted.head(10)
top10
# Out:
#                  nome      rank
# 0  vinicius de moraes  0.035680
# 1               titas  0.019286
# 2           nara leao  0.019286
# 3        gilberto gil  0.019286
# 4           tom jobim  0.019286
# 5      racionais mc's  0.019286
# 6       novos baianos  0.019286
# 7         elis regina  0.019286
# 8    martinho da vila  0.019286
# 9       jorge ben jor  0.019286

# %%
# Plotagem com anotação dos valores
plt.figure(figsize=(10, 6))
bars = plt.barh(top10['nome'][::-1], top10['rank'][::-1])
plt.xlabel('PageRank')
plt.title('Top 10 Artistas por Influência')
plt.gca().invert_yaxis()

# Anotar valor à direita de cada barra
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(width + 0.0005, y, f'{width:.2f}', va='center')

plt.tight_layout()
plt.show()

# %%
plt.figure(figsize=(16, 6))
bars = plt.bar(df_sorted['nome'], df_sorted['rank'])

plt.xlabel('Artista')
plt.ylabel('PageRank')
plt.title('PageRank de Todos os Artistas')

plt.xticks(rotation=90, fontsize=8)

# Adiciona os valores acima de cada barra
for bar in bars:
    height = bar.get_height()
    plt.text(
        bar.get_x() + bar.get_width() / 2,
        height,
        f'{height:.2f}',
        ha='center',
        va='bottom',
        fontsize=7
    )

plt.tight_layout()
plt.show()

# %% [markdown]
# A partir daqui usaremos outros artistas e a wikipedia como fonte dos dados

# %%
def get_wikipedia_content(artist_name):
    base_url = "https://pt.wikipedia.org/w/api.php"
    params = {
        'action': 'query',
        'format': 'json',
        'titles': artist_name,
        'prop': 'extracts',
        'explaintext': True,
        'redirects': True  # Para seguir redirecionamentos automaticamente
    }
    response = requests.get(base_url, params=params)
    if response.status_code == 200:
        data = response.json()
        pages = data.get('query', {}).get('pages', {})
        for page_id, page_data in pages.items():
            if page_id != "-1":
                return page_data.get('extract')  # Aqui está o texto puro da página
    return None

# Dicionário para armazenar os conteúdos
wikipedia_contents = {}

for artist in artistas_brasileiros:
    #print(f"Buscando conteúdo da Wikipédia para: {artist}")
    content = get_wikipedia_content(artist)
    if content:
        content = content.replace('\r', '').replace('\n', '')  # Remove \r
        wikipedia_contents[artist] = content
        #print(f"Conteúdo encontrado para: {artist}")
    else:
        print(f"Conteúdo não encontrado para: {artist}")
    time.sleep(1)  # 1 segundo parece ser o minimo de tempo necessario para nao ser bloqueado

# %%
print(*next(iter(wikipedia_contents.items()))) # primeiro key value pair de wikipedia contents
# Out:
# Tom Jobim Antônio Carlos Brasileiro de Almeida Jobim (Rio de Janeiro, 25 de janeiro de 1927 – Nova Iorque, 8 de dezembro de 1994), mais conhecido pelo seu nome artístico Tom Jobim, foi um compositor, pianista, violonista, arranjador, Flautista e cantor brasileiro. Considerado um dos grandes expoentes da música brasileira, Jobim internacionalizou a bossa nova e, com a ajuda de importantes artistas estadunidenses, fundiu-a com o jazz nos anos 1960 para criar uma nova sonoridade, de sucesso popular. Por isso, às vezes é conhecido como o "pai da bossa nova".Suas canções foram executadas por muitos cantores e instrumentistas internacionalmente desde o início da década de 1960. Em 1965, o álbum Getz/Gilberto foi o primeiro disco de jazz a ganhar o prêmio Grammy de Álbum do Ano. Ele também ganhou o prêmio nas categorias de Melhor Álbum Instrumental de Jazz e de Álbum Melhor Produzido. O single do álbum "Garota de Ipanema", composta por Jobim, tornou-se uma das canções mais gravadas de todos os tempos e o álbum ganhou o prêmio de Gravação do Ano. Jobim compôs muitas canções que hoje fazem parte dos repertórios clássicos do jazz e do pop. "Garota de Ipanema" já foi gravada mais de 240 vezes por outros artistas. Seu álbum de 1967 com Frank Sinatra, Francis Albert Sinatra e Antônio Carlos Jobim, foi indicado para Álbum do Ano em 1968.Em levantamento de 2022, produzido pelo ECAD, Tom tem 8 das 15 músicas brasileiras mais regravadas da história, contando canções solo ou em parceria, sendo a mais regravada Garota de Ipanema, que fez em parceria com Vinicius de Moraes.== Juventude ==Antônio Carlos Jobim nasceu na Rua Conde de Bonfim, 634, no bairro da Tijuca, no Rio de Janeiro. Seu pai, Jorge de Oliveira Jobim (São Gabriel, Rio Grande do Sul; 1889–1935), foi escritor, diplomata, professor e jornalista. Ele veio de uma família proeminente, sendo sobrinho-neto de José Martins da Cruz Jobim, senador, conselheiro particular e médico do imperador Dom Pedro II. Sua mãe, Nilza Brasileiro de Almeida (c. 1910–1989), era parcialmente descendente de indígenas do Nordeste do Brasil. Brasileira de Almeida tinha apenas 16 anos quando deu à luz Antônio Carlos Jobim em sua casa na Tijuca, na Rua Conde de Bonfim. Enquanto estudava medicina na Europa, José Martins acrescentou Jobim ao sobrenome, em homenagem à vila de onde veio sua família em Portugal, a freguesia de Santa Cruz de Jovim do município de Gondomar, na Área Metropolitana do Porto.Quando Antônio ainda era bebê, seus pais se separaram e sua mãe mudou-se com os filhos (Antônio Carlos e sua irmã Helena Isaura, nascidos em 23 de fevereiro de 1931) para Ipanema, bairro litorâneo que o compositor mais tarde celebraria em suas canções. Em 1935, com a morte do pai Jobim, Nilza casou-se com Celso da Frota Pessoa (falecido em 2 de fevereiro de 1979), que incentivaria a carreira do enteado. Foi ele quem deu a Jobim seu primeiro piano e quem o incentivou a seguir a música. Em entrevista a Roberto d'Ávila em 1981, ele disse: "Eu odiava piano, achava coisa de menina, gostava de jogar futebol... Tive um ótimo padrasto que me ajudou muito a me envolver com a música e me convenceu de que piano não era coisa de menina". Mais adiante na entrevista com Roberto d'Ávila, Jobim fala sobre seus sentimentos em relação à sua criação. Ele menciona uma conversa que teve com um amigo de seu pai, Erico Verissimo, que disse que Tom Jobim deveria estar sombrio pela ausência do pai desde jovem. Jobim disse a d'Ávila: “Fiquei sem pai, agarrado às saias da minha mãe... alguns [homens] têm pais 'excessivos', a presença excessiva dos pais é um problema, mas a ausência do pai também é um problema”. Jobim continuou com d'Ávila, compartilhando que é preciso algo de grande influência para levar alguém a dedicar sua vida à música. Ele disse que “as pessoas que tocam piano bem são todas deficientes”. Ele menciona os problemas de saúde de Sergio Mendes, que teve osteomielite, e de Luiz Eça, que teve poliomielite. “É preciso algo muito forte ...

# %%
dados_artistas_wikipedia = []

for artista, texto in wikipedia_contents.items():
    if not texto:
        continue

    palavras = texto.split()
    all_persons = []

    for i in range(0, len(palavras), 100):
        trecho = ' '.join(palavras[i:i + 100])
        ents = ner(trecho)
        persons = [e['word'] for e in ents if e['entity_group'] == 'Pessoa']
        all_persons.extend(persons)

    dados_artistas_wikipedia.append({
        'artista': artista,
        'entidades': all_persons
    })

#Para 5 artistas - 3 minutos de execucao na minha maquina

# %%
dados_artistas_wikipedia[0]
# Out:
# {'artista': 'Tom Jobim',
#  'entidades': ['Antônio Carlos Brasileiro de Almeida Jobim',
#   'Tom Jobim',
#   'Jobim',
#   'Getz',
#   'Gilberto',
#   'Jobim',
#   'Jobim',
#   'Frank Sinatra',
#   'Francis Albert Sinatra',
#   'Antônio Carlos Jobim',
#   'Vinicius de Moraes',
#   'Antônio Carlos Jobim',
#   'Jorge de Oliveira Jobim',
#   'José Martins da Cruz Jobim',
#   'Dom Pedro II',
#   'Nilza Brasileiro de Almeida',
#   'Brasileira de Almeida',
#   'Antônio Carlos Jobim',
#   'José Martins',
#   'Jobim',
#   'Antônio',
#   'Antônio Carlos',
#   'Helena Isaura',
#   'Jobim',
#   'Nilza',
#   'Celso da Frota Pessoa',
#   'Jobim',
#   "Roberto d ' Ávila",
#   "Roberto d ' Ávila",
#   'Jobim',
#   'Erico Verissimo',
#   'Tom Jobim',
#   'Jobim',
#   "d ' Ávila",
#   'Jobim',
#   'd',
#   "' Ávila",
#   'Sergio Mendes',
#   'Luiz Eça',
#   'Jobim',
#   'Jobim',
#   'Pixinguinha',
#   'Lúcia Branco',
#   'Hans',
#   '-',
#   'Joachim Koellreutter',
#   'Jobim',
#   'Koellreutter',
#   'Jobim',
#   'Claude Debussy',
#   'Maurice Ravel',
#   'Ary Barroso',
#   'Heitor Villa - Lobos',
#   'Jobim',
#   'Jane Pauley',
#   'Jobim',
#   'Jobim',
#   'Mauricy Moura',
#   'Jobim',
#   'Newton Mendonça',
#   'Jobim',
#   'Vinicius de Moraes',
#   'Sacha Gordine',
#   'Gordine',
#   'Moraes',
#   'Jobim',
#   'Moraes',
#   'Jobim',
#   'Moraes',
#   'Jobim',
#   'João Gilberto',
#   'Jobim',
#   'Jobim',
#   'Stan Getz',
#   'João Gilberto',
#   'Gilberto',
#   'Astrud Gilberto',
#   'Getz',
#   'Gilberto',
#   'Getz',
#   'Gilberto',
#   'Getz',
#   'Gilberto',
#   'Getz',
#   'Charlie Byrd',
#   'Luiz Bonfá',
#   'Jobim',
#   'Getz',
#   'Gilberto',
#   'Astrud Gilberto',
#   'Getz',
#   'Gilberto',
#   'Georges Moustaki',
#   'Jobim',
#   "Roberto d ' Ávila",
#   'Jobim',
#   'Elis Regina',
#   'Jobim',
#   'Elis Regina',
#   'Regina',
#   'Regina',
#   'Elis',
#   'Tom',
#   'Regina',
#   'Jobim',
#   'Oscar Castro - Neves',
#   'Regina',
#   'Jobim',
#   'Elis',
#   'Tom',
#   'Regina',
#   'Jobim',
#   'Jobim',
#   'Thereza Otero Hermanny',
#   'Paulo Jobim',
#   'Daniel Jobim',
#   'Dora Jobim',
#   'Elizabeth',
#   'Beth " Jobim',
#   'Jobim',
#   'Thereza',
#   'Ana Beatriz Lontra',
#   'João Francisco Jobim',
#   'Maria Luiza Helena Jobim',
#   'Daniel',
#   'Paulo',
#   'Antonio Brasileiro',
#   'Jobim',
#   'Roberto Hugo Costa Lima',
#   'Antonio Brasileiro',
#   'Jobim',
#   'Ella Fitzgerald',
#   'Frank Sinatra',
#   'Jobim',
#   'Ella Abraça Jobim',
#   'Francis Albert Sinatra',
#   'Antônio Carlos Jobim',
#   'Antonio Carlos Jobim',
#   'Jobim',
#   'Oscar Peterson',
#   'Herbie Hancock',
#   'Chick Corea',
#   'Toots Thielemans',
#   'Jobim',
#   'Jobim',
#   'Vinicius de Moraes',
#   'João Gilberto',
#   'Chico Buarque',
#   'Edu Lobo',
#   'Gal Costa',
#   'Elis Regina',
#   'Sérgio Mendes',
#   'Astrud Gilberto',
#   'Flora Purim',
#   'Jobim',
#   'Eumir Deodato',
#   'Nelson Riddle',
#   'Claus Ogerman',
#   'Jobim',
#   'Jobim',
#   'Elliott Smith',
#   'Antonio Carlos Jobim',
#   'Michael Franks',
#   'Jobim',
#   'George Michael',
#   'Jobim',
#   'Jobim',
#   'Astrud Gilberto',
#   'Tom',
#   'Desafinado',
#   'Antônio Carlos Jobim',
#   'Antonio Carlos Jobim',
#   '. Jobim',
#   'Matita Perê',
#   'Jobim',
#   'Antônio Brasileiro',
#   'Tom Jobim',
#   'João Bosco',
#   'Antonio Carlos Jobim',
#   'Jobim',
#   'Antonio Carlos JobimTom Jobim',
#   'Jobim']}

# %%
# Índices únicos de artistas + entidades
nomes_wikipedia = list({normalizar(d['artista']) for d in dados_artistas_wikipedia})
indices_wikipedia = {nome: i for i, nome in enumerate(nomes_wikipedia)}

# %%
matriz_adj_wikipedia = construir_matriz_adj(dados_artistas_wikipedia, indices_wikipedia)

# %%
plt.figure(figsize=(10, 10))
plt.imshow(matriz_adj_wikipedia, cmap='Greys', interpolation='none')
plt.title('Matriz de Adjacência - Wikipedia')
plt.xlabel('Origem')
plt.ylabel('Destino')
plt.colorbar(label='Peso')
plt.show()

# %%
matriz_trans_wikipedia = normalizar_colunas(matriz_adj_wikipedia)

# %%
ranks_wikipedia = page_rank(matriz_trans_wikipedia)

# %%
df_wikipedia = pd.DataFrame({
    'nome': nomes_wikipedia,
    'rank': ranks_wikipedia
})
df_wikipedia['rank'] = df_wikipedia['rank'].round(6)
df_wikipedia_sorted = df_wikipedia.sort_values('rank', ascending=False).reset_index(drop=True)

top10_wikipedia = df_wikipedia_sorted.head(10)
top10_wikipedia
# Out:
#                  nome      rank
# 0      caetano veloso  0.040974
# 1     francisco alves  0.032138
# 2        gilberto gil  0.030836
# 3         elis regina  0.030639
# 4    nana vasconcelos  0.030032
# 5      maria bethania  0.029363
# 6    egberto gismonti  0.029360
# 7  vinicius de moraes  0.028700
# 8           gal costa  0.025999
# 9       chico buarque  0.024866

# %%
plt.figure(figsize=(16, 6))
bars = plt.bar(df_wikipedia_sorted['nome'], df_wikipedia_sorted['rank'])

plt.xlabel('Artista')
plt.ylabel('PageRank')
plt.title('PageRank de Todos os Artistas - Wikipedia')

plt.xticks(rotation=90, fontsize=8)


plt.tight_layout()
plt.show()

# %%
# Plotagem com anotação dos valores
plt.figure(figsize=(10, 6))
bars = plt.barh(top10_wikipedia['nome'][::-1], top10_wikipedia['rank'][::-1])
plt.xlabel('PageRank')
plt.title('Top 10 Artistas por Influência - Wikipedia')
plt.gca().invert_yaxis()

# Anotar valor à direita de cada barra
for bar in bars:
    width = bar.get_width()
    y = bar.get_y() + bar.get_height() / 2
    plt.text(width + 0.0005, y, f'{width:.2f}', va='center')

plt.tight_layout()
plt.show()
